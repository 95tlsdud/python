# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv
import bs4

# %%
bs4.BeautifulSoup
html = urlopen("http://www.naver.com")
html

# %% [markdown]
# 1. 가장 원시적인 방법으로 네이버 크롤링하기

# %%
bsObject = BeautifulSoup(html, "html.parser")
bsObject.html
# Out:
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="origin" name="Referrer"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1100" name="viewport"/>
# <meta content="NAVER" name="apple-mobile-web-app-title">
# <meta content="index,nofollow" name="robots">
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
# <meta content="네이버" property="og:title"/>
# <meta content="https://www.naver.com/" property="og:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
# <meta content="summary" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# <meta content="https://www.naver.com/" name="twitter:url"/>
# ...

# %% [markdown]
# 2. head 만 읽기

# %%
bsObject.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <meta content="origin" name="Referrer"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1100" name="viewport"/>
# <meta content="NAVER" name="apple-mobile-web-app-title">
# <meta content="index,nofollow" name="robots">
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
# <meta content="네이버" property="og:title"/>
# <meta content="https://www.naver.com/" property="og:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
# <meta content="summary" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# <meta content="https://www.naver.com/" name="twitter:url"/>
# ...

# %% [markdown]
# 3. title만 따오기

# %%
bsObject.title
# Out:
# <title>NAVER</title>

# %%
bsObject.head.title
# Out:
# <title>NAVER</title>

# %% [markdown]
# 4. meta data

# %%
bsObject.head.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="origin" name="Referrer"/>,
#  <meta content="text/javascript" http-equiv="Content-Script-Type"/>,
#  <meta content="text/css" http-equiv="Content-Style-Type"/>,
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>,
#  <meta content="width=1100" name="viewport"/>,
#  <meta content="NAVER" name="apple-mobile-web-app-title">
#  <meta content="index,nofollow" name="robots">
#  <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
#  <meta content="네이버" property="og:title"/>
#  <meta content="https://www.naver.com/" property="og:url"/>
#  <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#  <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
#  <meta content="summary" name="twitter:card"/>
#  <meta content="" name="twitter:title"/>
#  <meta content="https://www.naver.com/" name="twitter:url"/>
# ...

# %% [markdown]
# 5. 결과값
# None
# origin
# text/javascript
# text/css
# IE=edge
# width=1100
# NAVER
# index,nofollow
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요
# 네이버
# https://www.naver.com/
# https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요
# summary
#
# https://www.naver.com/
# https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %%
for meta in bsObject.head.find_all('meta'):
    print(meta.get('content'))
# Out:
# None
# origin
# text/javascript
# text/css
# IE=edge
# width=1100
# NAVER
# index,nofollow
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요
# 네이버
# https://www.naver.com/
# https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요
# summary
#
# https://www.naver.com/
# https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %% [markdown]
# 6. meta 데이터 중 원하는 tag만 가져오기

# %%
bsObject.head.find("meta", {"name":"description"})
# Out:
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
# <meta content="네이버" property="og:title"/>
# <meta content="https://www.naver.com/" property="og:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
# <meta content="summary" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# <meta content="https://www.naver.com/" name="twitter:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description">
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://pm.pstatic.net/css/main_v190219.css" rel="stylesheet" type="text/css"/>
# <link href="https://pm.pstatic.net/css/webfont_v170623.css" rel="stylesheet" type="text/css"/>
# ...

# %% [markdown]
# 7. 결과 값
# '네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요'

# %%
bsObject.head.find("meta", {"name":"description"}).get('content')
# Out:
# '네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요'

# %%
8. 모든 링크의 텍스트와 주소 가져오기


연합뉴스 바로가기 #news_cast
주제별캐스트 바로가기 #themecast
타임스퀘어 바로가기 #time_square
쇼핑캐스트 바로가기 #shp_cst
로그인 바로가기 #account
네이버 /
네이버를 시작페이지로 http://help.naver.com/support/alias/contents2/naverhome/naverhome_1.naver
쥬니어네이버 http://jr.naver.com
해피빈 http://happybean.naver.com/main/SectionMain.nhn
자동완성 펼치기 javascript:;
한글 입력기 javascript:;
도움말 보기 https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=16658
ON선택됨 #
OFF #
로그인 https://nid.naver.com/nidlogin.login

# %%
for link in bsObject.find_all('a'):
    print(link.get_text(),link.get('href'))
# Out:
# 연합뉴스 바로가기 #news_cast
# 주제별캐스트 바로가기 #themecast
# 타임스퀘어 바로가기 #time_square
# 쇼핑캐스트 바로가기 #shp_cst
# 로그인 바로가기 #account
# 네이버를 시작페이지로 http://help.naver.com/support/alias/contents2/naverhome/naverhome_1.naver
# 쥬니어네이버 http://jr.naver.com
# 해피빈 http://happybean.naver.com/main/SectionMain.nhn
# 자동완성 펼치기 javascript:;
# 한글 입력기 javascript:;
# 도움말 보기 https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=16658
# ON선택됨 #
# OFF #
# 로그인 https://nid.naver.com/nidlogin.login
# 자세히 https://help.naver.com/support/alias/search/word/word_16.naver
# 자세히 https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=16659
# 도움말 https://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1987
# 신고 https://help.naver.com/support/contents/contents.nhn?serviceNo=605&categoryNo=18215
# 검색어저장 켜기 javascript:;
# 자동완성 끄기 javascript:;
# 도움말 https://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1987
# ...

# %%
html = urlopen('http://book.naver.com/bestsell/bestseller_list.nhn')
bsObject = BeautifulSoup(html, "html.parser")

# %%
html = urlopen('https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query=%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84')
bsObject = BeautifulSoup(html, "html.parser")

# %%
bsObject
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
bsObject.find_all('span')
# Out:
# [<span>메뉴 영역으로 바로가기</span>,
#  <span>본문 영역으로 바로가기</span>,
#  <span class="keyword"> <input accesskey="s" autocomplete="off" class="box_window" id="nx_query" maxlength="255" name="query" title="검색어 입력" type="text" value="영화순위"/> </span>,
#  <span class="spnew ico_keyboard">한글 입력기</span>,
#  <span class="blind _text">자동완성 펼치기</span>,
#  <span class="ico_arrow spnew"></span>,
#  <span class="spnew ico_search">검색</span>,
#  <span class="desc"> <span class="plus_txt">시간대와 관심사에 맞춘 <em class="txt">컨텍스트 자동완성</em></span> <a class="spat ico_info" href="https://help.naver.com/support/alias/search/word/word_16.naver" onclick="__atcmpCR(event, this, 'plus.help', '','','');" target="_blank"><span class="blind">도움말 보기</span></a> </span>,
#  <span class="plus_txt">시간대와 관심사에 맞춘 <em class="txt">컨텍스트 자동완성</em></span>,
#  <span class="blind">도움말 보기</span>,
# ...

# %%
bsObject.find('span', {"class":"ranking num01"})
# Out:
# <span class="ranking num01"><span class="blind">1</span></span>

# %%
bsObject.find_all('strong')
# Out:
# [<strong class="tit">컨텍스트 자동완성</strong>,
#  <strong class="calendar-title">2014.04</strong>,
#  <strong class="scm_ellipsis_text _text">돈</strong>,
#  <strong class="scm_ellipsis_text _text">캡틴 마블</strong>,
#  <strong class="scm_ellipsis_text _text">악질경찰</strong>,
#  <strong class="scm_ellipsis_text _text">우상</strong>,
#  <strong class="scm_ellipsis_text _text">이스케이프 룸</strong>,
#  <strong class="scm_ellipsis_text _text">페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이</strong>,
#  <strong class="scm_ellipsis_text _text">장난스런 키스</strong>,
#  <strong class="scm_ellipsis_text _text">라스트 미션</strong>,
#  <strong class="scm_ellipsis_text _text">양지의 그녀</strong>,
#  <strong class="scm_ellipsis_text _text">그린 북</strong>,
#  <strong class="scm_ellipsis_text _text">극한직업</strong>,
#  <strong class="scm_ellipsis_text _text">더 페이버릿: 여왕의 여자</strong>,
#  <strong class="scm_ellipsis_text _text">왓칭</strong>,
#  <strong class="scm_ellipsis_text _text">정글북: 마법 원정대</strong>,
# ...

# %%
for movie in bsObject.find_all('strong'):
    print(movie.get_text())
# Out:
# 컨텍스트 자동완성
# 2014.04
# 돈
# 캡틴 마블
# 악질경찰
# 우상
# 이스케이프 룸
# 페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이
# 장난스런 키스
# 라스트 미션
# 양지의 그녀
# 그린 북
# 극한직업
# 더 페이버릿: 여왕의 여자
# 왓칭
# 정글북: 마법 원정대
# 증인
# 항거:유관순 이야기
# 원 네이션
# 중공탈출
# 더 와이프
# 어스
# 아사코
# 가버나움
# 더 길티
# 콜드 체이싱
# 킹 오브 프리즘 -샤이니 세븐 스타즈-
# 사바하
# 에움길
# 애정의 쌀
# 숲속왕국의 꿀벌 여왕
#  현재 페이지 1
#  총 페이지 4
# 유의사항
# 영화
# 순위
# 영화
# 순위
# 순위
# 영화
# 영화 순위
# 영화 순위
# 영화순위
# 영화순위
# 영화 순위
# 영화
# 순위
# 영화 순위
# 영화
# 순위
# 영화순위
# 관련도순
# 영화순위
# 영화 순위
# 영화순위
# 영화순위
# 영화 순위
# 영화 순위
# 영화 순위
# 영화 순위
# 영화순위
# 영화순위
# 영화
# 순위
# 영화
# 영화
# 영화
# 순위
# 영화
# 순위
# 영화
# 순위
# 영화
# 영화
# 영화
# 순위
# 영화
# 영화
# 최신
# 순위
# 영화
# 순위
# 영화
# 영화
# 영화순위
# 영화
# 영화순위
# 영화
# 영화
# 랭킹
# 영화
# 영화
# 영화
# 순위
# 영화
# 영화
# 영화
# 영화
# 영화
# 영화
# 순위
# 영화
# 신고완료
# 영화 순위
# 영화순위
# 영화순위
# 영화순위
# 신고완료
# 순위
# 영화
# 영화
# 순위
# 영화
# 영화
# 영화
# 영화 순위
# 영화 순위
# 영화 순위
# 영화
# 순위
# 영화
# 순위
# 영화순위
# 영화순위
# 영화순위
# 영화순위
# 영화순위
# 앱정보
# 카페
# 지식iN
# 컨텍스트 자동완성

# %%
bsObject.find("strong",{"class":"scm_ellipsis_text _text"})
# Out:
# <strong class="scm_ellipsis_text _text">돈</strong>

# %%
bsObject.find_all("strong", {"class":"scm_ellipsis_text _text"})
# Out:
# [<strong class="scm_ellipsis_text _text">돈</strong>,
#  <strong class="scm_ellipsis_text _text">캡틴 마블</strong>,
#  <strong class="scm_ellipsis_text _text">악질경찰</strong>,
#  <strong class="scm_ellipsis_text _text">우상</strong>,
#  <strong class="scm_ellipsis_text _text">이스케이프 룸</strong>,
#  <strong class="scm_ellipsis_text _text">페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이</strong>,
#  <strong class="scm_ellipsis_text _text">장난스런 키스</strong>,
#  <strong class="scm_ellipsis_text _text">라스트 미션</strong>,
#  <strong class="scm_ellipsis_text _text">양지의 그녀</strong>,
#  <strong class="scm_ellipsis_text _text">그린 북</strong>,
#  <strong class="scm_ellipsis_text _text">극한직업</strong>,
#  <strong class="scm_ellipsis_text _text">더 페이버릿: 여왕의 여자</strong>,
#  <strong class="scm_ellipsis_text _text">왓칭</strong>,
#  <strong class="scm_ellipsis_text _text">정글북: 마법 원정대</strong>,
#  <strong class="scm_ellipsis_text _text">증인</strong>,
#  <strong class="scm_ellipsis_text _text">항거:유관순 이야기</strong>,
# ...

# %%
for movie in bsObject.find_all("strong", {"class":"scm_ellipsis_text _text"}):
    print(movie.get_text())
# Out:
# 돈
# 캡틴 마블
# 악질경찰
# 우상
# 이스케이프 룸
# 페이트 스테이 나이트 헤븐즈필 제2장 로스트 버터플라이
# 장난스런 키스
# 라스트 미션
# 양지의 그녀
# 그린 북
# 극한직업
# 더 페이버릿: 여왕의 여자
# 왓칭
# 정글북: 마법 원정대
# 증인
# 항거:유관순 이야기
# 원 네이션
# 중공탈출
# 더 와이프
# 어스
# 아사코
# 가버나움
# 더 길티
# 콜드 체이싱
# 킹 오브 프리즘 -샤이니 세븐 스타즈-
# 사바하
# 에움길
# 애정의 쌀
# 숲속왕국의 꿀벌 여왕

# %%
with open('crawling.csv', 'w') as f:
    writer = csv. writer(f)
    
    
    for movie in bsObject.find_all("strong", {"class":"scm_ellipsis_text _text"}):
        movie.get_text()

# %%
html = urlopen('http://corners.gmarket.co.kr/Bestsellers')
bsObject = BeautifulSoup(html, "html.parser")

# %%
bsObject
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <title>G마켓 - G마켓 베스트</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="text/css" http-equiv="content-style-type"/>
# <meta content="text/javascript" http-equiv="content-script-type"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <meta content="width=980" id="viewport" name="viewport"/>
# <meta content="all" name="ROBOTS"/>
# <meta content="인터넷쇼핑,오픈마켓,패션/뷰티,디지털,식품/유아,스포츠/자동차,생활용품,도서/DVD,여행/항공권,e쿠폰/티켓,만화/게임,공동구매,경매,중고,글로벌쇼핑,브랜드샵,베스트셀러,방문쇼핑몰,G스탬프,할인쿠폰,동영상,이벤트 등 G마켓" name="description"/>
# <meta content="베스트100,베스트셀러,경매,할인쿠폰,베스트셀러,공동구매,컴퓨터/핸드폰,에어컨/TV/디카,MP3/게임,패션/명품/브랜드,여성의류/속옷,남성의류/정장/빅사이즈,분유/기저귀/식품/생리대/임부복,유아동/장난감,쌀/과일/한우/생선,건강식품/음료,화장품/자동차,스포츠/다이어트,골프/등산/스키/낚시,운동화,네비게이션,리빙/침구/인테리어,애완/성인/공구,꽃배달,도서/여행/항공권,만화" name="keywords"/>
# ...

# %%
bsObject.find_all('a')
# Out:
# [<a name="top"></a>,
#  <a href="/BestSellers">G마켓 BEST</a>,
#  <a class="q_btn" id="aboutGBestLink">G마켓베스트란?</a>,
#  <a class="btn_close" id="closeGBestBtn">닫기</a>,
#  <a href="/BestSellers" onclick="pdsClickLog('200000683', 'Utility', {'viewType': 1});">그룹별</a>,
#  <a href="/BestSellers?viewType=C" onclick="pdsClickLog('200000683', 'Utility', {'viewType': 2});">카테고리별</a>,
#  <a class="q_btn" id="aboutGGroupCategoriBestLink">그룹별베스트, 카테고리별베스트란?</a>,
#  <a class="btn_close" id="closeGGCBestBtn">닫기</a>,
#  <a href="/Bestsellers">ALL</a>,
#  <a href="/Bestsellers?viewType=G&amp;groupCode=G01" onclick="pdsClickLog('200000676', 'Item', {'ASN': 1, 'groupCode': 'G01'});">패션의류</a>,
#  <a href="/Bestsellers?viewType=G&amp;groupCode=G02" onclick="pdsClickLog('200000676', 'Item', {'ASN': 2, 'groupCode': 'G02'});">신발/잡화</a>,
#  <a href="/Bestsellers?viewType=G&amp;groupCode=G03" onclick="pdsClickLog('200000676', 'Item', {'ASN': 3, 'groupCode': 'G03'});">화장품/헤어</a>,
# ...

# %%
bsObject.find_all("a", {"class":"itemname"})
# Out:
# [<a class="itemname" href="" id="topPlusItemName0"></a>,
#  <a class="itemname" href="" id="topPlusItemName1"></a>,
#  <a class="itemname" href="" id="topPlusItemName2"></a>,
#  <a class="itemname" href="" id="topPlusItemName3"></a>,
#  <a class="itemname" href="" id="topPlusItemName4"></a>,
#  <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=531241652" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '531241652'});">[이글립스]NEW 이글립스 립스틱/팩트/틴트 1+1 무배 외</a>,
#  <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=1573916992" onclick="pdsClickLog('200000680', 'Item', {'ASN': 2, 'goodsCode': '1573916992'});">[GS수퍼마켓]GS수퍼마켓 금액권2만원</a>,
#  <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=1342781681" onclick="pdsClickLog('200000680', 'Item', {'ASN': 3, 'goodsCode': '1342781681'});">[지오다노]지오다노 데일리 티셔츠/팬츠 특가전 (~71% SALE)</a>,
# ...

# %%
html = urlopen("https://audioclip.naver.com/panels/rank")
bsObject = BeautifulSoup(html, "html.parser")

# %%
bsObject
# Out:
# <!DOCTYPE html>
#
# <html data-useragent="Python-urllib/3.7" id="frameHtml" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="noindex,nofollow" name="robots">
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no, viewport-fit=cover" name="viewport"/>
# <title>오디오클립</title>
# <link href="https://ssl.pstatic.net/static/audio/img/icon/favicon.ico" rel="shortcut icon"/>
# <link href="https://ssl.pstatic.net/static/audio/img/icon/android-icon-72x72.png" rel="apple-touch-icon-precomposed">
# <link href="https://ssl.pstatic.net/static/audio/img/icon/android-icon-96x96.png" rel="apple-touch-icon-precomposed" sizes="96x96"/>
# <link href="https://ssl.pstatic.net/static/audio/img/icon/android-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# ...

# %%
bsObject.find_all('span')
# Out:
# [<span class="blind">오디오클립</span>,
#  <span class="blind">검색</span>,
#  <span class="blind">입력내용 초기화</span>,
#  <span class="text">닫기</span>,
#  <span class="text">카테고리</span>,
#  <span class="blind">자세히 보기</span>,
#  <span class="text">로그인</span>,
#  <span class="blind">카테고리 자세히보기</span>,
#  <span class="blind">카테고리 자세히보기</span>,
#  <span class="blind">카테고리 닫기</span>,
#  <span class="blind">마이 페이지</span>,
#  <span class="mypage_thumb">
#  <!-- 기본 프로필 사진 -->
#  <img alt="프로필" class="thumb_image" src="https://ssl.pstatic.net/static/audio/img/m/2018/img/img_user.png"/>
#  </span>,
#  <span class="text">홈</span>,
#  <span class="text">랭킹</span>,
#  <span class="text">연재 채널</span>,
#  <span class="text">오디오북</span>,
#  <span class="tab_text">채널</span>,
#  <span class="tab_text">클립</span>,
#  <span class="blind">카테고리 필터</span>,
#  <span class="blind">순위</span>,
#  <span class="text">
#                                          1
#                                  </span>,
# ...

# %%
bsObject.find_all('div')
# Out:
# [<div id="u_skip">
#  <a href="#content">본문으로 바로가기</a>
#  </div>, <div class="wrap is_home" id="wrap">
#  <!-- header -->
#  <!-- 상단배너 -->
#  <!--// 상단배너 -->
#  <!-- Header -->
#  <!-- [D]
#  엔드페이지에서 .is_fixed 클래스 제거해주세요.
#  -->
#  <header class="header is_fixed " id="header">
#  <div class="gnb" id="gnb">
#  <div class="gnb_primary" id="gnbPrimary">
#  <h1 class="gnb_logo logo">
#  <a class="link" href="/" onclick="nclk(this, 'gnb.audioclip', '', '');">
#  <span class="blind">오디오클립</span>
#  </a>
#  </h1>
#  <div class="gnb_search">
#  <div aria-hidden="true" class="gnb_search_button" id="gnbSearchButtonDiv">
#  <!-- [D]
#                          [MO] 클릭시 argnbSearchButtonDivia-expanded="true"로 변경.
#                               클릭시 #header에 .is_search_open 클래스 추가.
#                          [PC] aria-hidden="true" 추가
#                      -->
#  <a aria-controls="gnbSearchBar" aria-expanded="false" aria-haspopup="true" class="button_search" href="#" id="gnbSearchButton">
# ...

# %%
bsObject.find("div", {"class":"detail detail_title"})
# Out:
# <div class="detail detail_title">
#                                         컬투쇼 레전드 사연
#                                 </div>

# %%
for cast in bsObject.find_all("div", {"class":"detail detail_title"}):
    print(cast.get_text())
# Out:
#                                         컬투쇼 레전드 사연
#
#
#                                         [자장가] 꿈을 꾸는 소리
#
#
#                                         오은영 박사의 글로만 읽어서는 잘 안 되는 육아 듣기
#
#
#                                         우리 식탁의 수산물 상식
#
#
#                                         이재성 박사의 식탁보감
#
#
#                                         클래식매니저
#
#
#                                         요조와 임경선의 교환일기
#
#
#                                         엄마가 읽어주는 중국어 동화
#
#
#                                         [클래식클라우드] 김태훈의 책보다 여행
#
#
#                                         세상의 모든 소리 선아 ASMR
#
#
#                                         대입멘토 한수진
#
#
#                                         AESOP'S FABLES
#
#
#                                         이용의 거대한 장기판
#
#
#                                         매일 책 한권
#
#
#                                         세바시
#
#
#                                         시원스쿨 세상에 하나뿐인 영어동화
#
#
# ...

# %%
for cast in bsObject.find_all("div", {"class":"detail detail_title"}):
    print(cast.get_text())

# %%
for cast in bsObject.find_all("div", {"class":"detail detail_title"}):
    casts = cast.get_text()
    castss = casts.strip()
    print(castss)
# Out:
# 컬투쇼 레전드 사연
# [자장가] 꿈을 꾸는 소리
# 오은영 박사의 글로만 읽어서는 잘 안 되는 육아 듣기
# 우리 식탁의 수산물 상식
# 이재성 박사의 식탁보감
# 클래식매니저
# 요조와 임경선의 교환일기
# 엄마가 읽어주는 중국어 동화
# [클래식클라우드] 김태훈의 책보다 여행
# 세상의 모든 소리 선아 ASMR
# 대입멘토 한수진
# AESOP'S FABLES
# 이용의 거대한 장기판
# 매일 책 한권
# 세바시
# 시원스쿨 세상에 하나뿐인 영어동화
# [뮤직테라피]소리에 음악을 입히다
# 서천석의 아이와 나 - 실전편
# 버럭엄마, 우아하게 아이 키우기
# 이동우의 10분 독서
